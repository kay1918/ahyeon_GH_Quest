# %% [markdown]
# # 1. Web Crawling

# %% [markdown]
# ### Requests

# %%
import requests # urllib 말고 requests 써주세요 (urllib은 구식입니다!)

# %%
# requests.post에 url을 전달해주면, 해당 url의 html을 가져와줍니다.
url = "https://ghsnu.com/"

gh = requests.post(url)

status = gh.status_code

print("http status code : %s" % status) #200 : 정상, # 400  : Bad Request , # 500 Internal Server Error
# Out:
# http status code : 200

# %% [markdown]
# ### BeautifulSoup

# %%
from bs4 import BeautifulSoup as bs
import lxml

# %%
# bs 로 html parsing 하기 !
html =  """<html> <head> </head> <body> <p>hello gh</p> </body></html>"""

# html parser 보다 lxml이 더 빠릅니다.
soup = bs(html, "lxml")

# 원하는 부분 선택해서 출력 !

print(soup.p)

print(soup.text)
# Out:
# <p>hello gh</p>
#     hello gh

# %% [markdown]
# #### (1) GH 홈페이지 정보 crawling

# %%
# requests로 html 가져오고, bs로 parsing 하기!
url = "https://ghsnu.com/ABOUT-US"

gh_info = requests.post(url)

#parsing 하기 전에는 어떻게 생겼을까?
from pprint import pprint
pprint(gh_info.content)
# Out:
# (b'<!DOCTYPE html>\n<html lang="en" id="no-fouc">\n<head>\n<title>Growth Hacke'
#  b'rs in SNU</title>\n<!-- ig-cl-taiwan5 : live-creatorlink -->\n\n<link rel="'
#  b'dns-prefetch" href="//ghmkt.kr">\n<link rel="dns-prefetch" href="//storag'
#  b'e.googleapis.com">\n<link rel="dns-prefetch" href="//fonts.googleapis.com'
#  b'">\n<link rel="dns-prefetch" href="//connect.facebook.net">\n<link rel="dn'
#  b's-prefetch" href="//ajax.googleapis.com">\n<link rel="dns-prefetch" href='
#  b'"//www.google-analytics.com">\n<link rel="dns-prefetch" href="//pagead2.g'
#  b'ooglesyndication.com">\n<link rel="dns-prefetch" href="//googleads.g.doub'
#  b'leclick.net">\n\t<meta name="google-signin-scope" content="profile email">'
#  b'\n\t<meta id="google-meta" name="google-signin-client_id" content="">\n<!--'
#  b" user meta tag start -->\n<META name='author' content='PR in GH'/><META n"
#  b"ame='title' content='Growth Hackers in SNU'/><META name='description' conten"
# ...

# %%
#그렇다면 parsing을 한 후에는?
soup = bs(gh_info.content, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html id="no-fouc" lang="en">
# <head>
# <title>Growth Hackers in SNU</title>
# <!-- ig-cl-taiwan5 : live-creatorlink -->
# <link href="//ghmkt.kr" rel="dns-prefetch"/>
# <link href="//storage.googleapis.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//connect.facebook.net" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
# <meta content="profile email" name="google-signin-scope"/>
# <meta content="" id="google-meta" name="google-signin-client_id"/>
# <!-- user meta tag start -->
# ...

# %%
about_us = soup.find("p", {"class":"text-box"})

print(about_us.prettify())
# Out:
# <p class="text-box" data-edit="true" data-selector="p.text-box">
#  <span style="font-family: 'Jeju Myeongjo';">
#   <span style="color: rgb(0, 0, 0);">
#    <strong>
#     Growth Hackers
#    </strong>
#    는 데이터 기반 의사결정을 통해 비즈니스 가치 창출을 도모하는 학회입니다.
#    <br/>
#    우리는 통계분석과 예측모형으로 데이터를 가공하고, 인사이트를 추출하여
#    <br/>
#    비즈니스 목표 달성을 위한 마케팅 및 전략적 방향성을 제시하는 것을 목표로 합니다.
#    <br/>
#    본 학회는 서울대학교 계량마케팅 연구소 송인성 교수님의 지도 아래
#    <br/>
#    서울대학교 경영대학 학생들을 중심으로 2017년 여름학기에 설립되어 다양한 학교의 학생들이 함께 하고 있습니다.
#   </span>
#  </span>
# </p>

# %%
print(about_us.text) #태그, 속성 등 제외하고 내용만 가져오고 싶을 때
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-77ffd27460b2> in <module>
# ----> 1 print(about_us.text) #태그, 속성 등 제외하고 내용만 가져오고 싶을 때
#
# NameError: name 'about_us' is not defined

# %% [markdown]
# #### (2) 일일 박스 오피스 정보 crawling

# %%
# 이번엔 일일 박스오피스 정보를 가져와보자 !

url = "http://www.kobis.or.kr/kobis/business/main/main.do"

kobis = requests.post(url)

soup = bs(kobis.content, 'lxml')

daily_boxoffice = soup.find("div", {"id":"dailyBoxOffice"})

print(daily_boxoffice) # ?? 분명 내용이 있었는데 ??
# Out:
# <div class="item_slide" id="dailyBoxOffice">
# <div class="hd_cont">
# <h2 class="tit">일별 박스오피스<a class="more" href="/kobis/business/stat/boxs/findDailyBoxOfficeList.do"><span class="ico_comm ico_plus"></span></a></h2>
# </div>
# <div class="ovf">
# <div class="wrap_tbl fr">
# <table class="tb1">
# <caption class="blind">일일 박스오피스</caption>
# <colgroup>
# <col width="30"/><col width="145"/><col width="130"/><col width="100"/><col width=""/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col"><span class="blind">순위</span></th>
# <th scope="col"><span class="blind">제목</span></th>
# <th scope="col">매출액</th>
# <th scope="col">관객수</th>
# <th scope="col"><span class="blind">순위 변동</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tac">1</td>
# <td><span class="ellip"></span></td>
# <td></td>
# <td></td>
# <td class="tal"><span class="keep">-</span></td>
# </tr>
# <tr>
# <td class="tac">2</td>
# <td><span class="ellip"></span></td>
# <td></td>
# <td></td>
# ...

# %% [markdown]
# ### Selenium

# %%
from selenium import webdriver # 자바스크립트로 전송 되는 데이터는 url - html에 안붙어있습니다.. 페이지를 열어줘야 데이터가 와요!
import time
import requests
from selenium.webdriver.common.keys import Keys

# %%
path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

# 기다려줍시다
driver.implicitly_wait(3) #혹은 time.sleep(3)

# %%
driver.get("http://www.kobis.or.kr/kobis/business/main/main.do")

driver.implicitly_wait(3)

# %%
daily_boxoffice_html = driver.page_source
print(daily_boxoffice_html)
# Out:
# <html lang="ko"><head>
# <meta http-equiv="X-UA-Compatible" content="IE=EmulateIE10" charset="utf-8">
# <title>KOFIC 영화관 입장권 통합전산망(2)</title>
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/default.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/jquery-ui-1.12.1.min.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/kobis.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/common.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/main/main.css">
#
# ...

# %%
parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'lxml')

# %%
daily_boxoffice = parsed_daily_boxoffice_html.find("div", {"id":"dailyBoxOffice"})

print(daily_boxoffice.prettify())
# Out:
# <div aria-hidden="false" class="item_slide" id="dailyBoxOffice" style="float: left; list-style: none; position: relative; width: 1200px;">
#  <div class="hd_cont">
#   <h2 class="tit">
#    일별 박스오피스
#    <a class="more" href="/kobis/business/stat/boxs/findDailyBoxOfficeList.do">
#     <span class="ico_comm ico_plus">
#     </span>
#    </a>
#   </h2>
#  </div>
#  <div class="ovf">
#   <div class="wrap_tbl fr">
#    <table class="tb1">
#     <caption class="blind">
#      일일 박스오피스
#     </caption>
#     <colgroup>
#      <col width="30"/>
#      <col width="145"/>
#      <col width="130"/>
#      <col width="100"/>
#      <col width=""/>
#     </colgroup>
#     <thead>
#      <tr>
#       <th scope="col">
#       </th>
#       <th class="tac" scope="col">
#        영화명
#       </th>
#       <th scope="col">
#        매출액
#       </th>
#       <th scope="col">
#        관객수
#       </th>
#       <th scope="col">
#        증감율
#       </th>
#      </tr>
#     </thead>
#     <tbody>
# ...

# %%
movie_list = daily_boxoffice.find_all("td", {"class":"tac"})
movie_list
# money_list = daily_boxoffice.find_all("td", {"style":"cursor:default"})
for movie in movie_list:
    print(movie.find_next_sibling("td").find_next_sibling("td").text)
# Out:
# 526,530,270 원
# 217,903,930 원
# 181,626,290 원
# 159,523,000 원
# 117,694,790 원
# 100,037,300 원
# 49,990,000 원
# 33,219,000 원
# 30,123,000 원
# 28,255,000 원

# %%
movie_list = daily_boxoffice.find_all("td", {"class":"tac"})
for movie in movie_list:
    title = movie.find_next_sibling("td").text
    earning = movie.find_next_sibling("td").find_next_sibling("td").text
    audience = movie.find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text
    print("movie : {} {} {}".format(title, earning, audience))
# Out:
# movie : 나쁜 녀석들: 더 무비 526,530,270 원 65,946 명
# movie : 애드 아스트라 217,903,930 원 26,323 명
# movie : 타짜: 원 아이드 잭 181,626,290 원 22,523 명
# movie : 퍼펙트맨 159,523,000 원 21,932 명
# movie : 예스터데이 117,694,790 원 14,973 명
# movie : 힘을 내요, 미스터 리 100,037,300 원 13,612 명
# movie : 양자물리학 49,990,000 원 8,570 명
# movie : 장사리 : 잊혀진 영웅들 33,219,000 원 3,644 명
# movie : 가장 보통의 연애 30,123,000 원 3,347 명
# movie : 그것: 두 번째 이야기 28,255,000 원 3,278 명

# %%
for movie in movie_list:
    print("Movie title : %s" % movie.find_next_sibling("td").text)
    print("Earning : %s" % movie.find_next_sibling("td").find_next_sibling("td").text)
    print("Audience : %s" % movie.find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text)


    # title이 뒤에 조금 짤려 나와서 확인해보니, 원래 메인 페이지에서 이렇게만 나온다.
# Out:
# Movie title : 나쁜 녀석들: 더 무비
# Earning : 526,530,270 원
# Audience : 65,946 명
# Movie title : 애드 아스트라
# Earning : 217,903,930 원
# Audience : 26,323 명
# Movie title : 타짜: 원 아이드 잭
# Earning : 181,626,290 원
# Audience : 22,523 명
# Movie title : 퍼펙트맨
# Earning : 159,523,000 원
# Audience : 21,932 명
# Movie title : 예스터데이
# Earning : 117,694,790 원
# Audience : 14,973 명
# Movie title : 힘을 내요, 미스터 리
# Earning : 100,037,300 원
# Audience : 13,612 명
# Movie title : 양자물리학
# Earning : 49,990,000 원
# Audience : 8,570 명
# Movie title : 장사리 : 잊혀진 영웅들
# Earning : 33,219,000 원
# Audience : 3,644 명
# Movie title : 가장 보통의 연애
# Earning : 30,123,000 원
# Audience : 3,347 명
# Movie title : 그것: 두 번째 이야기
# Earning : 28,255,000 원
# Audience : 3,278 명

# %%
driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_0").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조
'''
혹시 
WebDriverException: Message: Element is not clickable at point (918, 13). Other element would receive the click: <div class="linkAuchan"></div>
와 같은 에러가 뜰 시에는
driver.find_element_by_id("btn_0").click()  이 코드를 아래의

element = driver.find_element_by_id("btn_0")
driver.execute_script("arguments[0].click();", element)  이 코드로 대체하면 해결할 수 있다.
'''
driver.implicitly_wait(4)

driver.find_element_by_id("btn_0").click()

daily_boxoffice_html = driver.page_source

driver.quit()

#간혹 연결을 거부 당하는 경우가 있다
#그럴땐 아래 링크 참조!
#https://www.notion.so/sunnybaik/cc78acee7a0047d68db530eac017f6b9

# %%
#연결을 거부당했을 시
chrome_options = webdriver.ChromeOptions()

from pprint import pprint
pprint (vars(chrome_options))

chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"')

from pprint import pprint
pprint (vars(chrome_options))
# Out:
# {'_arguments': [],
#  '_binary_location': '',
#  '_caps': {'browserName': 'chrome', 'platform': 'ANY', 'version': ''},
#  '_debugger_address': None,
#  '_experimental_options': {},
#  '_extension_files': [],
#  '_extensions': []}
# {'_arguments': ['--user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
#                 'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 '
#                 'Safari/537.36"'],
#  '_binary_location': '',
#  '_caps': {'browserName': 'chrome', 'platform': 'ANY', 'version': ''},
#  '_debugger_address': None,
#  '_experimental_options': {},
#  '_extension_files': [],
#  '_extensions': []}

# %%
driver = webdriver.Chrome(options=chrome_options)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_0").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(4)

driver.find_element_by_id("btn_0").click()

daily_boxoffice_html = driver.page_source

driver.quit()

# %%
parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'lxml')

daily_boxoffice = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_0"})

movie_list = daily_boxoffice.find_all("tr")

# %%
print("Daily_boxoffice : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
#The strip() method returns a copy of the string in which all chars have been stripped from the beginning and the end of the string (default whitespace characters).
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text

    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
# Out:
# Daily_boxoffice : 2019년 09월 24일(화)
#
# ------------------------------
# 영화명 : 나쁜 녀석들: 더 무비
# 순위 변동 : 동일
# 개봉일 : 2019-09-11
# 매출액 : 526,530,270
# 매출액점유율 : 32.3%
# 관객수 : 65,946
# 누적관객수 : 4,048,569
# 스크린수 : 1,114
# 상영횟수 : 5,236
# ------------------------------
# 영화명 : 애드 아스트라
# 순위 변동 : 동일
# 개봉일 : 2019-09-19
# 매출액 : 217,903,930
# 매출액점유율 : 13.4%
# 관객수 : 26,323
# 누적관객수 : 409,432
# 스크린수 : 787
# 상영횟수 : 3,179
# ------------------------------
# 영화명 : 타짜: 원 아이드 잭
# 순위 변동 : 동일
# 개봉일 : 2019-09-11
# 매출액 : 181,626,290
# 매출액점유율 : 11.1%
# 관객수 : 22,523
# 누적관객수 : 2,160,504
# 스크린수 : 777
# 상영횟수 : 2,661
# ------------------------------
# 영화명 : 퍼펙트맨
# 순위 변동 : 2상승
# 개봉일 : 2019-10-02
# 매출액 : 159,523,000
# 매출액점유율 : 9.8%
# 관객수 : 21,932
# 누적관객수 : 55,273
# 스크린수 : 147
# 상영횟수 : 164
# ------------------------------
# 영화명 : 예스터데이
# 순위 변동 : 1하락
# 개봉일 : 2019-09-18
# 매출액 : 117,694,790
# 매출액점유율 : 7.2%
# 관객수 : 14,973
# 누적관객수 : 258,450
# 스크린수 : 630
# 상영횟수 : 2,161
# ------------------------------
# 영화명 : 힘을 내요, 미스터 리
# ...

# %%
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
print(daily_movies)
# Out:
# {'영화명': ['나쁜 녀석들: 더 무비', '애드 아스트라', '타짜: 원 아이드 잭', '퍼펙트맨', '예스터데이', '힘을 내요, 미스터 리', '양자물리학', '장사리 : 잊혀진 영웅들', '가장 보통의 연애', '그것: 두 번째 이야기', '원스 어폰 어 타임... 인 할리우드', '엑시트', '암전', '벌새', '극장판 헬로카봇 : 달나라를 구해줘!', '유열의 음악앨범', '사자', '레드슈즈', '100일 동안 100가지로 100퍼센트 행복찾기', '뷰티풀 보이', '비뚤어진 집', '안녕, 티라노: 영원히, 함께', '변신', '봉오동 전투', '내 완벽한 남사친의 비밀', '슈퍼 햄찌', '몬스터 하우스', '전원사형', '발명왕 볼트', '사랑의 선물'], '순위 변동': ['동일', '동일', '동일', '2상승', '1하락', '1하락', '2상승', '5상승', 'New', '1하락', '3상승', '1하락', '5상승', '6하락', '5하락', '1상승', '동일', '8상승', '3하락', '8하락', '7하락', '0상승', '4상승', '3상승', '4상승', '8하락', 'New', '2하락', '9상승', '8하락'], '개봉일': ['2019-09-11', '2019-09-19', '2019-09-11', '2019-10-02', '2019-09-18', '2019-09-11', '2019-09-25', '2019-09-25', '2019-10-02', '2019-09-04', '2019-09-25', '2019-07-31', '2019-08-15', '2019-08-29', '2019-09-04', '2019-08-28', '2019-07-31', '2019-07-25', '2019-09-12', '2019-09-19', '2019-09-19', '2019-08-14', '2019-08-21', '2019-08-07', '2019-03-27', '2019-09-26', '2019-10-03', '2019-05-13
# ...

# %%
daily_boxoffice = pd.DataFrame(daily_movies) 

daily_boxoffice
# Out:
#                            영화명 순위 변동         개봉일          매출액 매출액점유율     관객수  \
# 0                 나쁜 녀석들: 더 무비    동일  2019-09-11  526,530,270  32.3%  65,946
# 1                      애드 아스트라    동일  2019-09-19  217,903,930  13.4%  26,323
# 2                  타짜: 원 아이드 잭    동일  2019-09-11  181,626,290  11.1%  22,523
# 3                         퍼펙트맨   2상승  2019-10-02  159,523,000   9.8%  21,932
# 4                        예스터데이   1하락  2019-09-18  117,694,790   7.2%  14,973
# 5                 힘을 내요, 미스터 리   1하락  2019-09-11  100,037,300   6.1%  13,612
# 6                        양자물리학   2상승  2019-09-25   49,990,000   3.1%   8,570
# 7                장사리 : 잊혀진 영웅들   5상승  2019-09-25   33,219,000   2.0%   3,644
# 8                    가장 보통의 연애   New  2019-10-02   30,123,000   1.8%   3,347
# 9                 그것: 두 번째 이야기   1하락  2019-09-04   28,255,000   1.7%   3,278
# 10        원스 어폰 어 타임... 인 할리우드   3상승  2019-09-25   20,200,000   1.2%   2,020
# ...

# %%
# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice['순위 변동'] = daily_boxoffice['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
#                            영화명 순위 변동         개봉일          매출액 매출액점유율     관객수  \
# 0                 나쁜 녀석들: 더 무비     0  2019-09-11  526,530,270  32.3%  65,946
# 1                      애드 아스트라     0  2019-09-19  217,903,930  13.4%  26,323
# 2                  타짜: 원 아이드 잭     0  2019-09-11  181,626,290  11.1%  22,523
# 3                         퍼펙트맨     2  2019-10-02  159,523,000   9.8%  21,932
# 4                        예스터데이    -1  2019-09-18  117,694,790   7.2%  14,973
# 5                 힘을 내요, 미스터 리    -1  2019-09-11  100,037,300   6.1%  13,612
# 6                        양자물리학     2  2019-09-25   49,990,000   3.1%   8,570
# 7                장사리 : 잊혀진 영웅들     5  2019-09-25   33,219,000   2.0%   3,644
# 8                    가장 보통의 연애   New  2019-10-02   30,123,000   1.8%   3,347
# 9                 그것: 두 번째 이야기    -1  2019-09-04   28,255,000   1.7%   3,278
# 10        원스 어폰 어 타임... 인 할리우드     3  2019-09-25   20,200,000   1.2%   2,020
# ...

# %% [markdown]
# ### Headless Chrome (참고)

# %%
from selenium import webdriver

# 크롬 드라이버를 쓸 때, headless option을 주면 브라우저가 열리지 않고 빠르게 동작한다.

options = webdriver.ChromeOptions()

options.add_argument('headless')

options.add_argument('window-size=1920x1080')

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path, options=options)

driver.get('https://ghmkt.kr/MEMBERS/view/1051225')

driver.get_screenshot_as_file('capture.png')

# 자동화를 할 때는 헤드리스 옵션 + window-size 옵션을 주는 것이 좋음 !
# Out:
# True

# %% [markdown]
# ### 데이터 관리 - crawling을 통해 수집한 데이터를 어떻게 관리할 것인가?

# %% [markdown]
# ### (1) JSON

# %%
key = "712f41a54281c08443a79e1930d9dbc8"
#http://www.kobis.or.kr/kobisopenapi/homepg/apiservice/searchServiceInfo.do
api_data = requests.get("http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=20190923&itemPerPage=10" % key)

# %%
import json

json_data = json.loads(api_data.content.decode("utf-8")) # json 형식으로 받았으니, parsing도 json 기준으로!

print(json_data)

# %%
movie_list = json_data['boxOfficeResult']['dailyBoxOfficeList']

pd.DataFrame(movie_list) # 훨씬 빠르고 쉽게 데이터를 가져올 수 있다 .. ! 하지만 OPEN API 마다 가져올 수 있는 데이터 종류 / 범위 / 양이 다르다
# kobis의 경우 boxoffice 10개씩 가져오는 걸로 제한이 되어 있다 .. 10위까지 밖에 못가져옴
# Out:
#    audiAcc audiChange audiCnt audiInten   movieCd               movieNm  \
# 0  3982648      -69.1   75680   -169619  20188750          나쁜 녀석들: 더 무비
# 1   383117      -71.5   30134    -75459  20192982               애드 아스트라
# 2  2138001      -65.7   26061    -49897  20184572           타짜: 원 아이드 잭
# 3   243481      -69.2   16466    -37078  20193807                 예스터데이
# 4  1132561        -71   12719    -31139  20187322          힘을 내요, 미스터 리
# 5    33341        100    2640      2640  20184483                  퍼펙트맨
# 6     4848        100    2320      2320  20195968                   더 룸
# 7    95354      -48.5    1988     -1873  20181103                    벌새
# 8   585680      -66.6    1213     -2417  20192804          그것: 두 번째 이야기
# 9   559701        -95    1097    -20748  20193821  극장판 헬로카봇 : 달나라를 구해줘!
#
#        openDt rank rankInten rankOldAndNew rnum     salesAcc   salesAmt  \
# 0  2019-09-11    1         0           OLD    1  34864447224  609623940
# ...

# %% [markdown]
# ### (2) CSV

# %%
daily_boxoffice.to_csv('daily_boxoffice.csv', encoding = 'utf-8')
pd.read_csv('daily_boxoffice.csv', encoding = 'utf-8').head()
# Out:
#    Unnamed: 0      영화명  순위 변동         개봉일            매출액 매출액점유율      관객수  \
# 0           0        돈      0  2019-03-20  3,753,484,160  59.7%  416,174
# 1           1    캡틴 마블      0  2019-03-06  1,275,784,220  20.3%  142,382
# 2           2     악질경찰      0  2019-03-20    427,941,590   6.8%   46,589
# 3           3       우상      0  2019-03-20    254,358,090   4.0%   28,126
# 4           4  이스케이프 룸      0  2019-03-14    214,363,930   3.4%   23,494
#
#        누적관객수   스크린수   상영횟수
# 0  1,536,407  1,431  7,433
# 1  5,232,849    947  3,768
# 2    189,604    718  2,513
# 3    137,880    659  1,884
# 4    544,462    491  1,060

# %% [markdown]
# ### (3) PICKLE

# %%
import pickle

daily_boxoffice.to_pickle("daily_boxoffice.pickle")

with open('daily_boxoffice.pickle', 'rb') as f:
    data = pickle.load(f)

data.head()
# Out:
#        영화명  순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수  \
# 0        돈      0  2019-03-20  3,753,484,160  59.7%  416,174  1,536,407
# 1    캡틴 마블      0  2019-03-06  1,275,784,220  20.3%  142,382  5,232,849
# 2     악질경찰      0  2019-03-20    427,941,590   6.8%   46,589    189,604
# 3       우상      0  2019-03-20    254,358,090   4.0%   28,126    137,880
# 4  이스케이프 룸      0  2019-03-14    214,363,930   3.4%   23,494    544,462
#
#     스크린수   상영횟수
# 0  1,431  7,433
# 1    947  3,768
# 2    718  2,513
# 3    659  1,884
# 4    491  1,060

# %% [markdown]
# ### (4) SQLITE

# %%
import sqlite3

con = sqlite3.connect("daily_boxoffice.db")

con.execute("CREATE TABLE IF NOT EXISTS boxoffice(title text, rank int, open text, earning int, earning_share text, audiences int, total_audiences int, num_screen int, num_play int)")

# %%
daily_boxoffice.to_sql("boxoffice", con, chunksize=1000, if_exists='replace')
# Out:
# C:\Users\jungbin\Anaconda3\envs\gh\lib\site-packages\pandas\core\generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)

# %%
con.commit()

con.close()

# %%
# 다시 db에 연결해서 데이터를 불러와보자!
import sqlite3
import pandas as pd

con = sqlite3.connect("daily_boxoffice.db")

cursor = con.cursor()

cursor.execute("SELECT * FROM boxoffice")

data = cursor.fetchall()

# %%
pd.DataFrame(data)
# Out:
#      0                                   1  2           3              4  \
# 0    0                                   돈  0  2019-03-20  3,753,484,160
# 1    1                               캡틴 마블  0  2019-03-06  1,275,784,220
# 2    2                                악질경찰  0  2019-03-20    427,941,590
# 3    3                                  우상  0  2019-03-20    254,358,090
# 4    4                             이스케이프 룸  0  2019-03-14    214,363,930
# 5    5                         정글북: 마법 원정대  0  2019-03-21     90,106,890
# 6    6      페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이  0  2019-03-21     48,092,180
# 7    7                              라스트 미션  1  2019-03-14     27,805,210
# 8    8                                그린 북 -1  2019-01-09     23,715,060
# 9    9                             장난스런 키스  0  2019-03-27     30,718,400
# 10  10                              양지의 그녀  0  2019-03-21     21,809,820
# 11  11                      더 페이버릿: 여왕의 여자  0  2019-02-21     14,167,530
# ...

# %%
# 데이터 row를 하나 추가해보자.

new_row = ['30','괴물', -50, '2011-01-03', '2,000,000','0.0%','500','2,396,163','16','16']

con.execute("REPLACE INTO boxoffice VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?);", new_row)

con.commit()

# %%
# 이렇게 불러오는 게 더 깔끔하다.
cursor.execute("SELECT * FROM boxoffice")

data = cursor.fetchall()

df = pd.read_sql("SELECT * FROM boxoffice", con, index_col='index')

df
# Out:
#                                       영화명  순위 변동         개봉일            매출액  \
# index
# 0                                       돈      0  2019-03-20  3,753,484,160
# 1                                   캡틴 마블      0  2019-03-06  1,275,784,220
# 2                                    악질경찰      0  2019-03-20    427,941,590
# 3                                      우상      0  2019-03-20    254,358,090
# 4                                 이스케이프 룸      0  2019-03-14    214,363,930
# 5                             정글북: 마법 원정대      0  2019-03-21     90,106,890
# 6          페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이      0  2019-03-21     48,092,180
# 7                                  라스트 미션      1  2019-03-14     27,805,210
# 8                                    그린 북     -1  2019-01-09     23,715,060
# 9                                 장난스런 키스      0  2019-03-27     30,718,400
# 10                                 양지의 그녀      0  2019-03-21     21,809,820
# ...

# %% [markdown]
# # 2. Twitter API Crawling

# %% [markdown]
# ## (1). Twitter 데이터 수집하기
#
# 트위터는 데이터를 수집할 수 있는 API를 제공한다. API는 크게 다음과 같은 두가지로 제공된다.
# * REST API - 주어진 query에 맞는 데이터를 제공한다.
# * Streaming API - 제시된 키워드 등이 포함된 데이터를 streaming 해준다.
#
# 트위터 API에 대응하는 여러 라이브러리가 있지만, 본 예제에서는 tweepy 를 사용한다. tweepy의 설치는 다음과 같다.
# * pip install tweepy
#
# 트위터는 OAuth 인증을 통해 데이터에 접근이 가능하다. OAuth 인증을 하기 위해서는 트위터 개발자 사이트에 등록하고, 데이터 수집을 위한 앱을 등록해야 한다. 등록을 마치면 OAuth 인증을 위한 키가 제공되는데 해당 키를 이용하여 트위터 API를 사용할 수 있다.
#
# (강의 슬라이드 참고)

# %% [markdown]
# ### tweepy 및 OAuth 설정

# %%
import tweepy

# OAuth setup
consumer_key = '8KNlzBS83cCTtMwI9I8wsJZaZ'
consumer_secret = 'eqwp4fXiUZLVPSXYOzChhDBUm9YVZ9N26u9Mw75mifp8T1dQ6f'
access_token = '1193758207673397248-PC5en8kM2yj1JIKtbgls0du0NdKK7V'
access_secret = 'LMdIbBlHAOn57li05bHPcvBqcjxa9FkJvQxphIUQ3O4yv'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# %% [markdown]
# ### tweepy api 오브젝트 생성

# %%
api = tweepy.API(auth)

# %% [markdown]
# ### Streaming Tweet Data
#
# Streaming API는 rate limit의 제한이 없어 트윗을 수집할 때 유용하다. 그러나 모든 트윗을 제공하는 것은 아니고, 전체 트윗의 1%만을 random 으로 제공해 준다.
#
# Streaming API를 사용하여 트윗을 수집하려면 다음과 같은 순서를 따른다.
#
# * StreamListener 클래스를 상속받은 lister 클래스를 만든다.
# * Stream 오브젝트를 생성한다.
# * Stream 오브젝트에 Twitter API를 연결한다.

# %% [markdown]
# #### 1. StreamListener 클래스 생성

# %%
import tweepy

class MyListener(tweepy.StreamListener): #tweepy.StreamListener를 상속받아서 MyListener를 만든다. 
    
    def on_status(self, data):
        print(data.text + "\n----")

# %% [markdown]
# on_status는 StreamListener에 이미 구현이 되어 있는 함수이다!!

# %% [markdown]
# #### 2. Stream 오브젝트 생성하고 Twitter API 연결 (OAuth 설정)

# %%
twitter_stream = tweepy.Stream(auth, MyListener())

# %% [markdown]
# #### 3. Streaming 시작

# %%
twitter_stream.filter(track=['수학']) #jupyter notebook은 memory관리에 썩 좋지 않다! terminal에서 돌릴 것!

# %% [markdown]
# #### 4. json 파일로 저장할 수 있도록 MyListener 클래스 수정

# %%
class MyListener(tweepy.StreamListener):
    
    def on_data(self, data): #on_data라는 것을 수정하려고 한다. json파일이 append하는 것이다!
        try:
            with open('tweet_stream.json', 'a') as file:
                file.write(data)
                print(data)
                return True
        except BaseException as e:
            print("Error on_data: {}".format(str(e)))
        return True

# %%
twitter_stream = tweepy.Stream(auth, MyListener())
twitter_stream.filter(track=['trump', 'korea'])
# Out:
# {"created_at":"Sat Nov 16 12:57:08 +0000 2019","id":1195687245824561153,"id_str":"1195687245824561153","text":"RT @mitchellvii: Sorry Pelosi, it is not Trump's job to \"prove his innocence.\"  One cannot prove a negative.\n\nHis innocence is presumed in\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":361444464,"id_str":"361444464","name":"Zalia","screen_name":"welzZalia","location":null,"url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":196,"friends_count":231,"listed_count":29,"favourites_count":3321,"statuses_count":33968,"created_at":"Wed Aug 24 20:02:57 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_t
# ...

# %% [markdown]
# (참고1) ```on_status vs. on_data```
#
# ```on_status```는 데이터를 tweepy object 형태로 return한다. 따라서 data.text와 같은 notation이 가능하다. 하지만 ```on_data```는 데이터를 str로 return 한다. 우리는 데이터를 .json 파일로 저장할 것이기 때문에 tweepy object보다는 str로 저장하여야 한다. 따라서 두번째 수정된 코드에서는 ```on_data```를 사용하였다.
#
# (참고2) ```on_status vs. on_data```
#
# 두개의 메소드는 StreamListener에 구현되어 있다. 클래스를 상속 받으면 부모 클래스에 구현된 메소드를 재정의(override)해서 사용할 수 있다.
#
# ### 터미널에서 프로그램 실행
#
# jupyter notebook이 편리하긴 하지만 어떤 경우에는 터미널에서 프로그램을 실행하여야 한다. 스트리밍한 데이터를 저장하는 프로그램은 계속 데이터를 받아오기 때문에 jupyter notebook에서 실행하면 메모리 로드가 많아 작동불능 상태에 빠지기 쉽다. 따라서 이 경우 터미널에서 프로그램을 실행시킨다.
#
# * 첫번째 스트리밍 코드는 twitter-stream.py 로 저장되어 있다.
# * 수정된 두번째 스트리밍 코드는 twitter-stream-save.py로 저장되어 있다.
#
# 실행은 터미널에서 다음과 같이 한다.
#
# * python twitter-stream-save.py
#
# 프로그램의 종료는 CTRL-C 를 누른다

# %% [markdown]
# ### JSON 파일 불러오기

# %%
import json

json_data = []
with open("tweet_stream.json") as file:
    data = file.readlines()
    for d in data:
        try:
            json_data.append(json.loads(d))
        except:
            pass
        
        
#만약에 json에서 null에서 error가 날 경우 try (append하고) except(pass)이렇게!

# %%
i = 0
for tweet in json_data:
    if ("text" in tweet) and ("user" in tweet):
        print(str(i) + " - " + tweet["user"]["name"] + " :: " + tweet["text"])
        print("---")
        i = i + 1

# %% [markdown]
# # 3. OpenAPI Crawling

# %% [markdown]
# 지금까지 살펴본 Twitter나 Facebook은 해당 서비스의 데이터 크롤링을 위한 파이썬 라이브러리를 이용하여 데이터를 수집할 수 있었다. 이들 라이브러리는 Twitter나 Facebook이 제공하는 OpenAPI에 맞게 개발되었다. 모든 서비스를 위한 라이브러리가 제공되는지는 않기 때문에 특정 서비스의 OpenAPI를 이용하려면 OpenAPI가 제공하는 방식에 맞게 프로그램을 설계하고 데이터를 수집한다.
#
# 대개 OpenAPI는 다음과 같은 형식의 URL을 이용하여 필요한 자료를 API 서버에 request 한다. (call)
# * (포맷) http://web-address/api-name?param1=xxx&param2=xxx&param3=xxx
# * (사례) http://api.openweathermap.org/data/2.5/weather?q=Seoul&units=metric&appid=yourkey
#
# API서버가 call을 받으면 다음과 같이 JSON 포맷으로 결과를 반환한다. (response)
# ```
# {
#     "coord":{"lon":126.98,"lat":37.57},
#     "weather":[
#          {"id":701,"main":"Mist","description":"mist","icon":"50d"},
#          {"id":500,"main":"Rain","description":"light rain","icon":"10d"},
#          {"id":721,"main":"Haze","description":"haze","icon":"50d"}
#     ],
#     "base":"stations",
#     "main":{"temp":11.01,"pressure":1022,"humidity":43,"temp_min":10,"temp_max":12},
#     "visibility":10000,
#     "wind":{"speed":3.1,"deg":360},
#     "clouds":{"all":90},
#     "dt":1541917800,
#     "sys":{"type":1,"id":7668,"message":0.0054,"country":"KR","sunrise":1541887637,"sunset":1541924664},
#     "id":1835848,
#     "name":"Seoul",
#     "cod":200
# }
# ```
#
# 이와 같이 API를 사용하기 위해서는 공개된 OpenAPI라 하더라도 개발자로 등록을 해야 한다.
#
# 개발자로 등록을 한 후에는 데이터 수집을 위해 제작할 application을 등록한다.
#
# application을 등록하면 보통 app-key라는 것을 주는데, 이것은 일종의 아이디-패스워드이다. 즉, 누가 접속을 해서 데이터를 수집해가는 지를 서버에 알려주는 역할을 하며, 또한 서버 입장에서 데이터를 수집하는 앱의 트래픽을 콘트롤하기도 한다. (대개의 경우 call 숫자가 정해져 있다.)
#
# 본 예제에서는 openweathermap.org에서 제공하는 공개 데이터를 사용해 보고자 한다. 개발자 등록과 앱 등록은 슬라이드를 참고하자.

# %% [markdown]
# ### 앱 기본 설정
#
# app_key와 base_url 등 기본 설정을 한다.

# %% [markdown]
# 미세먼지 정보를 가져와보자.
#
# 미세먼지와 관련된 정보는 다음의 API를 활용할 예정이다.
#
# * http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-1204&srvType=A&serviceKind=1
#
# 데이터 수집을 위해서는 인증키(위의 App Key와 유사)을 받아야 하는데, 인증키 신청 버튼을 눌러 발급받도록 하자. 몇가지 form을 작성하면 키가 발급된다.
#
# 도큐멘테이션에 나와았는 API의 사용은 다음과 같다.
#
# * http://openAPI.seoul.go.kr:8088/(인증키)/xml/ForecastWarningMinuteParticleOfDustService/1/1/
#
# 위의 URL의 (인증키) 부분에는 발급받은 인증키를 넣도록 하자.
#
# 현재 이 URL은 XML 형태로 데이터를 제공한다. xml을 json으로 바꿔서 json 형식으로 데이터를 받아보자.

# %%
import urllib.request
import json
   
mykey  = ""
base_url = "http://openAPI.seoul.go.kr:8088/{}/json/ForecastWarningMinuteParticleOfDustService/1/1/ ".format(mykey)

fine_dust_data = ""
with urllib.request.urlopen(base_url) as response:
    fine_dust_data = json.loads(response.read().decode("utf-8"))

# %%
fine_dust_data

# %%
from datetime import datetime

time_observation = datetime.strptime(fine_dust_data["ForecastWarningMinuteParticleOfDustService"]["row"][0]["APPLC_DT"], "%Y%m%d%H%M")
dust_grade = fine_dust_data["ForecastWarningMinuteParticleOfDustService"]["row"][0]["CAISTEP"]
dust_grade

# · 0∼30 : 좋음 · 31∼80 : 보통 · 81∼150 : 나쁨 · 151 이상 : 매우 나쁨

# %%
warning = ""
if dust_grade == "매우 나쁨":
    warning = "외출을 자제하시는 것이 좋습니다."
elif dust_grade == "나쁨":
    warning = "외출시 꼭 마스크를 착용하세요."
elif dust_grade == "보통":
    warning = "마음껏 외출하세요."
else:
    warning = "너무 좋은 날씨네요. 마음껏 외출하세요 :)"
    
message = "{}년 {}월 {}일 {}시 현재, 미세먼지 수준은 {}입니다. ".format(time_observation.year, time_observation.month, time_observation.day, time_observation.hour, dust_grade)

print(message + warning)
